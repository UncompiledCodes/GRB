# %%
import tabula

# %%
tables = tabula.read_pdf("tables.pdf", pages = "28-34", multiple_tables = True, encoding="utf-8")
# Out:
# Got stderr: May 12, 2021 7:09:22 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for greaterorsimilar (38) in font MBVNDY+txsya

# %%
print(tables)
# Out:
# [   Unnamed: 0 Unnamed: 1          (a) Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0         GRB          z            E      LX(b)  Early flare(c)      UL(d)
# 1         NaN        NaN          iso        NaN             NaN        NaN
# 2      970228      0.695  1.65 ± 0.16        NaN             NaN        NaN
# 3      970828      0.958   30.4 ± 3.6        NaN             NaN        NaN
# 4      971214       3.42   22.1 ± 2.7        NaN             NaN        NaN
# 5      980329        3.5     267 ± 53        NaN             NaN        NaN
# 6      980703      0.966  7.42 ± 0.74        NaN             NaN        NaN
# 7      990123        1.6     241 ± 39        NaN             NaN        NaN
# 8      990506        1.3   98.1 ± 9.9        NaN             NaN        NaN
# 9      990510      1.619   18.1 ± 2.7        NaN             NaN        NaN
# 10     990705      0.842   18.7 ± 2.7        NaN             NaN        NaN
# ...
